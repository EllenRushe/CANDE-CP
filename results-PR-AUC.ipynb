# %%
import numpy as np
import json
import glob
import pandas as pd

# %%
model_names = [
               'AE_sound_all', 
               'AE_sound_FiLM_one_hot',
               'AE_sound_FiLM_embed_64'
            ]

# %%
def get_results_print(model_name, context=""):
    if context:
        iter_files = glob.glob("results/{}/{}/results_checkpoint_{}_{}_iter_*.json".format(model_name, context, model_name, context))
    else:
        iter_files = glob.glob("results/{}/results_checkpoint_{}__iter_*.json".format(model_name, model_name))
    assert len(iter_files)==3
    iters_results_df = []
    for iter_file in iter_files:
        with open(iter_file) as iter_f:
            iter_file_json = json.load(iter_f)
            context_keys = sorted(list(dict(iter_file_json).keys()))
            results_dict = dict()
            for key in context_keys:
                results_dict[key] = iter_file_json[key]["PR-AUC"] 
            results_df = pd.DataFrame.from_dict(results_dict, orient='index', columns=[model_name])
            iters_results_df.append(results_df)
    mean = pd.concat(iters_results_df).groupby(level=0).mean().round(3).astype(str)
    std = pd.concat(iters_results_df).groupby(level=0).std().round(3).astype(str)
    return mean+"±"+std


results_list_print = []
for model_name in model_names:
    results_list_print.append(get_results_print(model_name))
single_model_list_print = []
for i in range(16):
    single_model_list_print.append(get_results_print("AE_sound", context=str(i)))

single_model_results_print = pd.concat(single_model_list_print)

results_df_print = pd.concat([single_model_results_print]+results_list_print, axis=1)
results_df_print
# Out:
#                      AE_sound AE_sound_all AE_sound_FiLM_one_hot  \
# fan_0_0dB         0.564±0.011  0.521±0.021           0.523±0.023
# fan_0_6dB         0.783±0.005  0.644±0.019           0.719±0.034
# fan_0_min6dB       0.54±0.005  0.518±0.015            0.51±0.014
# fan_1_0dB         0.816±0.045   0.67±0.054            0.848±0.01
# fan_1_6dB         0.963±0.005  0.913±0.012           0.947±0.015
# fan_1_min6dB      0.593±0.005  0.485±0.011           0.622±0.012
# fan_2_0dB         0.682±0.007  0.614±0.006           0.663±0.007
# fan_2_6dB         0.912±0.003  0.847±0.014           0.858±0.011
# fan_2_min6dB      0.462±0.003  0.431±0.004           0.445±0.006
# fan_3_0dB         0.963±0.003  0.704±0.079           0.892±0.012
# fan_3_6dB         0.998±0.002   0.913±0.01           0.934±0.001
# fan_3_min6dB      0.754±0.018  0.464±0.024            0.659±0.03
# pump_4_0dB        0.399±0.036  0.273±0.022           0.378±0.041
# pump_4_6dB        0.593±0.069  0.295±0.048           0.467±0.052
# pump_4_min6dB     0.332±0.009  0.305±0.016           0.349±0.038
# pump_5_0dB        0.249±0.013  0.266±0.034           0.261±0.019
# pump_5_6dB        0.256±0.028    0.28±0.03            0.28±0.025
# pump_5_min6dB      0.19±0.014  0.239±0.023           0.232±0.021
# pump_6_0dB        0.878±0.043   0.482±0.09           0.878±0.019
# pump_6_6dB        0.968±0.017   0.61±0.064           0.934±0.029
# pump_6_min6dB     0.752±0.023  0.414±0.073           0.793±0.022
# pump_7_0dB        0.234±0.029  0.161±0.002             0.2±0.019
# pump_7_6dB        0.286±0.076  0.153±0.001           0.201±0.034
# pump_7_min6dB      0.22±0.012  0.176±0.004           0.195±0.014
# slider_8_0dB      0.934±0.005  0.919±0.008           0.947±0.006
# slider_8_6dB        0.992±0.0  0.981±0.009           0.992±0.001
# slider_8_min6dB   0.842±0.009   0.857±0.01           0.858±0.021
# slider_9_0dB      0.357±0.007  0.505±0.042           0.687±0.043
# slider_9_6dB      0.256±0.007   0.369±0.04             0.7±0.094
# slider_9_min6dB   0.356±0.006  0.399±0.019           0.496±0.024
# slider_10_0dB     0.669±0.093  0.706±0.008           0.749±0.013
# slider_10_6dB     0.731±0.208  0.778±0.017           0.818±0.015
# slider_10_min6dB   0.54±0.025  0.568±0.003           0.606±0.016
# slider_11_0dB     0.265±0.012  0.334±0.025           0.283±0.009
# slider_11_6dB     0.369±0.007  0.519±0.031           0.391±0.005
# slider_11_min6dB  0.255±0.007  0.269±0.013           0.253±0.006
# valve_12_0dB      0.201±0.009  0.154±0.001           0.186±0.013
# valve_12_6dB       0.195±0.03   0.141±0.01           0.177±0.008
# valve_12_min6dB    0.221±0.01  0.171±0.003           0.204±0.011
# valve_13_0dB      0.331±0.002   0.37±0.018            0.35±0.004
# valve_13_6dB      0.372±0.007  0.439±0.016           0.429±0.021
# valve_13_min6dB    0.253±0.01  0.283±0.004           0.272±0.007
# valve_14_0dB       0.28±0.026  0.191±0.013           0.244±0.009
# valve_14_6dB      0.298±0.032  0.176±0.007           0.243±0.001
# valve_14_min6dB   0.205±0.016  0.169±0.007           0.194±0.008
# valve_15_0dB      0.232±0.013  0.207±0.003           0.217±0.002
# valve_15_6dB      0.275±0.009  0.269±0.017           0.268±0.002
# valve_15_min6dB   0.214±0.012  0.195±0.001             0.189±0.0
#
#                  AE_sound_FiLM_embed_64
# fan_0_0dB                   0.541±0.015
# fan_0_6dB                   0.733±0.011
# fan_0_min6dB                0.519±0.011
# fan_1_0dB                   0.856±0.006
# fan_1_6dB                   0.935±0.013
# fan_1_min6dB                0.628±0.014
# fan_2_0dB                   0.662±0.025
# fan_2_6dB                   0.846±0.014
# fan_2_min6dB                0.457±0.014
# fan_3_0dB                   0.949±0.031
# fan_3_6dB                   0.961±0.021
# fan_3_min6dB                0.768±0.078
# pump_4_0dB                  0.458±0.075
# pump_4_6dB                  0.526±0.069
# pump_4_min6dB               0.409±0.047
# pump_5_0dB                  0.279±0.044
# pump_5_6dB                   0.286±0.06
# pump_5_min6dB               0.239±0.032
# pump_6_0dB                  0.869±0.018
# pump_6_6dB                  0.916±0.015
# pump_6_min6dB               0.784±0.012
# pump_7_0dB                  0.227±0.042
# pump_7_6dB                   0.24±0.068
# pump_7_min6dB               0.207±0.022
# slider_8_0dB                 0.93±0.011
# slider_8_6dB                0.986±0.004
# slider_8_min6dB             0.833±0.017
# slider_9_0dB                0.643±0.072
# slider_9_6dB                0.622±0.175
# slider_9_min6dB             0.482±0.039
# slider_10_0dB               0.799±0.032
# slider_10_6dB               0.841±0.021
# slider_10_min6dB            0.634±0.025
# slider_11_0dB               0.294±0.017
# slider_11_6dB               0.407±0.048
# slider_11_min6dB            0.254±0.002
# valve_12_0dB                0.183±0.006
# valve_12_6dB                0.178±0.024
# valve_12_min6dB              0.198±0.01
# valve_13_0dB                 0.349±0.01
# valve_13_6dB                0.422±0.025
# valve_13_min6dB             0.269±0.001
# valve_14_0dB                 0.238±0.02
# valve_14_6dB                0.232±0.013
# valve_14_min6dB             0.189±0.015
# valve_15_0dB                 0.224±0.01
# valve_15_6dB                0.282±0.015
# valve_15_min6dB             0.188±0.002

# %%
def get_results(model_name, context=""):
    if context:
        iter_files = glob.glob("results/{}/{}/results_checkpoint_{}_{}_iter_*.json".format(model_name, context, model_name, context))
    else:
        iter_files = glob.glob("results/{}/results_checkpoint_{}__iter_*.json".format(model_name, model_name))
    assert len(iter_files)==3
    iters_results_df = []
    for iter_file in iter_files:
        with open(iter_file) as iter_f:
            iter_file_json = json.load(iter_f)
            context_keys = sorted(list(dict(iter_file_json).keys()))
            results_dict = dict()
            for key in context_keys:
                results_dict[key] = iter_file_json[key]["PR-AUC"] 
            results_df = pd.DataFrame.from_dict(results_dict, orient='index', columns=[model_name])
            iters_results_df.append(results_df)
    return pd.concat(iters_results_df).groupby(level=0).mean()

results_list = []
for model_name in model_names:
    results_list.append(get_results(model_name))
single_model_list = []
for i in range(16):
    single_model_list.append(get_results("AE_sound", context=str(i)))

single_model_results = pd.concat(single_model_list)

results_df = pd.concat([single_model_results]+results_list, axis=1)
results_df
# Out:
#                   AE_sound  AE_sound_all  AE_sound_FiLM_one_hot  \
# fan_0_0dB         0.563611      0.521202               0.523298
# fan_0_6dB         0.782511      0.644092               0.718783
# fan_0_min6dB      0.540336      0.517800               0.509575
# fan_1_0dB         0.815896      0.669976               0.848042
# fan_1_6dB         0.962612      0.913277               0.947119
# fan_1_min6dB      0.593092      0.484591               0.621518
# fan_2_0dB         0.681993      0.614448               0.663144
# fan_2_6dB         0.912412      0.846696               0.857841
# fan_2_min6dB      0.461719      0.431164               0.444574
# fan_3_0dB         0.963147      0.703757               0.892197
# fan_3_6dB         0.997760      0.913126               0.934452
# fan_3_min6dB      0.754015      0.463649               0.659280
# pump_4_0dB        0.398509      0.273456               0.377732
# pump_4_6dB        0.593065      0.294622               0.467332
# pump_4_min6dB     0.332346      0.305295               0.348674
# pump_5_0dB        0.249362      0.265812               0.260975
# pump_5_6dB        0.255605      0.279588               0.280008
# pump_5_min6dB     0.190023      0.238558               0.231831
# pump_6_0dB        0.877780      0.482379               0.878441
# pump_6_6dB        0.968278      0.609848               0.933798
# pump_6_min6dB     0.751540      0.414306               0.792621
# pump_7_0dB        0.234271      0.161036               0.199667
# pump_7_6dB        0.285826      0.152874               0.200848
# pump_7_min6dB     0.219970      0.175983               0.195196
# slider_8_0dB      0.934281      0.918693               0.947145
# slider_8_6dB      0.991685      0.980527               0.992406
# slider_8_min6dB   0.842451      0.856566               0.858361
# slider_9_0dB      0.357246      0.505059               0.687330
# slider_9_6dB      0.255591      0.369441               0.700081
# slider_9_min6dB   0.356405      0.399298               0.496277
# slider_10_0dB     0.668862      0.706058               0.748839
# slider_10_6dB     0.731107      0.778349               0.817551
# slider_10_min6dB  0.540257      0.568331               0.605609
# slider_11_0dB     0.265345      0.334276               0.282988
# slider_11_6dB     0.369436      0.519092               0.390756
# slider_11_min6dB  0.254987      0.268577               0.253089
# valve_12_0dB      0.201390      0.153648               0.186198
# valve_12_6dB      0.195348      0.141147               0.177108
# valve_12_min6dB   0.221010      0.170735               0.204093
# valve_13_0dB      0.331430      0.370187               0.349751
# valve_13_6dB      0.372484      0.439317               0.429111
# valve_13_min6dB   0.252812      0.282935               0.271843
# valve_14_0dB      0.279878      0.190915               0.243973
# valve_14_6dB      0.297791      0.175778               0.242591
# valve_14_min6dB   0.204944      0.169335               0.194459
# valve_15_0dB      0.232418      0.207091               0.216696
# valve_15_6dB      0.275159      0.268677               0.267623
# valve_15_min6dB   0.214071      0.194806               0.189062
#
#                   AE_sound_FiLM_embed_64
# fan_0_0dB                       0.541235
# fan_0_6dB                       0.732986
# fan_0_min6dB                    0.518713
# fan_1_0dB                       0.855876
# fan_1_6dB                       0.934815
# fan_1_min6dB                    0.627942
# fan_2_0dB                       0.661559
# fan_2_6dB                       0.846472
# fan_2_min6dB                    0.457461
# fan_3_0dB                       0.949474
# fan_3_6dB                       0.961199
# fan_3_min6dB                    0.768078
# pump_4_0dB                      0.457601
# pump_4_6dB                      0.526184
# pump_4_min6dB                   0.408750
# pump_5_0dB                      0.278871
# pump_5_6dB                      0.286147
# pump_5_min6dB                   0.238633
# pump_6_0dB                      0.869397
# pump_6_6dB                      0.916413
# pump_6_min6dB                   0.784257
# pump_7_0dB                      0.227323
# pump_7_6dB                      0.240170
# pump_7_min6dB                   0.206551
# slider_8_0dB                    0.930359
# slider_8_6dB                    0.985614
# slider_8_min6dB                 0.832555
# slider_9_0dB                    0.643090
# slider_9_6dB                    0.622236
# slider_9_min6dB                 0.481536
# slider_10_0dB                   0.799161
# slider_10_6dB                   0.841408
# slider_10_min6dB                0.634451
# slider_11_0dB                   0.293962
# slider_11_6dB                   0.406884
# slider_11_min6dB                0.254329
# valve_12_0dB                    0.183469
# valve_12_6dB                    0.177624
# valve_12_min6dB                 0.197539
# valve_13_0dB                    0.349498
# valve_13_6dB                    0.421603
# valve_13_min6dB                 0.268823
# valve_14_0dB                    0.237564
# valve_14_6dB                    0.231902
# valve_14_min6dB                 0.189004
# valve_15_0dB                    0.223974
# valve_15_6dB                    0.282344
# valve_15_min6dB                 0.187572

# %%
rank_results_df = results_df[
          [
               'AE_sound',
               'AE_sound_all', 
               'AE_sound_FiLM_one_hot',
               'AE_sound_FiLM_embed_64'
            ]
        ].rank(1, ascending=False, method='first')
mean_rank_row = rank_results_df.mean().to_frame().T
mean_rank_row = mean_rank_row.rename(index={0: 'average rank'})
results_and_ranks_df = pd.concat([results_df, mean_rank_row])
results_and_ranks_df
# Out:
#                   AE_sound  AE_sound_all  AE_sound_FiLM_one_hot  \
# fan_0_0dB         0.563611      0.521202               0.523298
# fan_0_6dB         0.782511      0.644092               0.718783
# fan_0_min6dB      0.540336      0.517800               0.509575
# fan_1_0dB         0.815896      0.669976               0.848042
# fan_1_6dB         0.962612      0.913277               0.947119
# fan_1_min6dB      0.593092      0.484591               0.621518
# fan_2_0dB         0.681993      0.614448               0.663144
# fan_2_6dB         0.912412      0.846696               0.857841
# fan_2_min6dB      0.461719      0.431164               0.444574
# fan_3_0dB         0.963147      0.703757               0.892197
# fan_3_6dB         0.997760      0.913126               0.934452
# fan_3_min6dB      0.754015      0.463649               0.659280
# pump_4_0dB        0.398509      0.273456               0.377732
# pump_4_6dB        0.593065      0.294622               0.467332
# pump_4_min6dB     0.332346      0.305295               0.348674
# pump_5_0dB        0.249362      0.265812               0.260975
# pump_5_6dB        0.255605      0.279588               0.280008
# pump_5_min6dB     0.190023      0.238558               0.231831
# pump_6_0dB        0.877780      0.482379               0.878441
# pump_6_6dB        0.968278      0.609848               0.933798
# pump_6_min6dB     0.751540      0.414306               0.792621
# pump_7_0dB        0.234271      0.161036               0.199667
# pump_7_6dB        0.285826      0.152874               0.200848
# pump_7_min6dB     0.219970      0.175983               0.195196
# slider_8_0dB      0.934281      0.918693               0.947145
# slider_8_6dB      0.991685      0.980527               0.992406
# slider_8_min6dB   0.842451      0.856566               0.858361
# slider_9_0dB      0.357246      0.505059               0.687330
# slider_9_6dB      0.255591      0.369441               0.700081
# slider_9_min6dB   0.356405      0.399298               0.496277
# slider_10_0dB     0.668862      0.706058               0.748839
# slider_10_6dB     0.731107      0.778349               0.817551
# slider_10_min6dB  0.540257      0.568331               0.605609
# slider_11_0dB     0.265345      0.334276               0.282988
# slider_11_6dB     0.369436      0.519092               0.390756
# slider_11_min6dB  0.254987      0.268577               0.253089
# valve_12_0dB      0.201390      0.153648               0.186198
# valve_12_6dB      0.195348      0.141147               0.177108
# valve_12_min6dB   0.221010      0.170735               0.204093
# valve_13_0dB      0.331430      0.370187               0.349751
# valve_13_6dB      0.372484      0.439317               0.429111
# valve_13_min6dB   0.252812      0.282935               0.271843
# valve_14_0dB      0.279878      0.190915               0.243973
# valve_14_6dB      0.297791      0.175778               0.242591
# valve_14_min6dB   0.204944      0.169335               0.194459
# valve_15_0dB      0.232418      0.207091               0.216696
# valve_15_6dB      0.275159      0.268677               0.267623
# valve_15_min6dB   0.214071      0.194806               0.189062
# average rank      2.229167      3.250000               2.333333
#
#                   AE_sound_FiLM_embed_64
# fan_0_0dB                       0.541235
# fan_0_6dB                       0.732986
# fan_0_min6dB                    0.518713
# fan_1_0dB                       0.855876
# fan_1_6dB                       0.934815
# fan_1_min6dB                    0.627942
# fan_2_0dB                       0.661559
# fan_2_6dB                       0.846472
# fan_2_min6dB                    0.457461
# fan_3_0dB                       0.949474
# fan_3_6dB                       0.961199
# fan_3_min6dB                    0.768078
# pump_4_0dB                      0.457601
# pump_4_6dB                      0.526184
# pump_4_min6dB                   0.408750
# pump_5_0dB                      0.278871
# pump_5_6dB                      0.286147
# pump_5_min6dB                   0.238633
# pump_6_0dB                      0.869397
# pump_6_6dB                      0.916413
# pump_6_min6dB                   0.784257
# pump_7_0dB                      0.227323
# pump_7_6dB                      0.240170
# pump_7_min6dB                   0.206551
# slider_8_0dB                    0.930359
# slider_8_6dB                    0.985614
# slider_8_min6dB                 0.832555
# slider_9_0dB                    0.643090
# slider_9_6dB                    0.622236
# slider_9_min6dB                 0.481536
# slider_10_0dB                   0.799161
# slider_10_6dB                   0.841408
# slider_10_min6dB                0.634451
# slider_11_0dB                   0.293962
# slider_11_6dB                   0.406884
# slider_11_min6dB                0.254329
# valve_12_0dB                    0.183469
# valve_12_6dB                    0.177624
# valve_12_min6dB                 0.197539
# valve_13_0dB                    0.349498
# valve_13_6dB                    0.421603
# valve_13_min6dB                 0.268823
# valve_14_0dB                    0.237564
# valve_14_6dB                    0.231902
# valve_14_min6dB                 0.189004
# valve_15_0dB                    0.223974
# valve_15_6dB                    0.282344
# valve_15_min6dB                 0.187572
# average rank                    2.187500

# %%
with open("machine_ids_map", "r") as f:
    machine_id_map = json.load(f)
inv_machine_id_map = {v: k for k, v in machine_id_map.items()}
results_df[["Machine Name", "id", "SNR"]] = pd.DataFrame([x.split('_') for x in results_and_ranks_df.index.tolist()], index=results_and_ranks_df.index)
results_df["ID"] = pd.to_numeric(results_df["id"])
results_df["ID"] = results_df["ID"].map(inv_machine_id_map)
results_df["ID"] = pd.DataFrame([x.split('_')[-1] for x in results_df["ID"].tolist()], index=results_df.index)
results_df
# Out:
#                   AE_sound  AE_sound_all  AE_sound_FiLM_one_hot  \
# fan_0_0dB         0.563611      0.521202               0.523298
# fan_0_6dB         0.782511      0.644092               0.718783
# fan_0_min6dB      0.540336      0.517800               0.509575
# fan_1_0dB         0.815896      0.669976               0.848042
# fan_1_6dB         0.962612      0.913277               0.947119
# fan_1_min6dB      0.593092      0.484591               0.621518
# fan_2_0dB         0.681993      0.614448               0.663144
# fan_2_6dB         0.912412      0.846696               0.857841
# fan_2_min6dB      0.461719      0.431164               0.444574
# fan_3_0dB         0.963147      0.703757               0.892197
# fan_3_6dB         0.997760      0.913126               0.934452
# fan_3_min6dB      0.754015      0.463649               0.659280
# pump_4_0dB        0.398509      0.273456               0.377732
# pump_4_6dB        0.593065      0.294622               0.467332
# pump_4_min6dB     0.332346      0.305295               0.348674
# pump_5_0dB        0.249362      0.265812               0.260975
# pump_5_6dB        0.255605      0.279588               0.280008
# pump_5_min6dB     0.190023      0.238558               0.231831
# pump_6_0dB        0.877780      0.482379               0.878441
# pump_6_6dB        0.968278      0.609848               0.933798
# pump_6_min6dB     0.751540      0.414306               0.792621
# pump_7_0dB        0.234271      0.161036               0.199667
# pump_7_6dB        0.285826      0.152874               0.200848
# pump_7_min6dB     0.219970      0.175983               0.195196
# slider_8_0dB      0.934281      0.918693               0.947145
# slider_8_6dB      0.991685      0.980527               0.992406
# slider_8_min6dB   0.842451      0.856566               0.858361
# slider_9_0dB      0.357246      0.505059               0.687330
# slider_9_6dB      0.255591      0.369441               0.700081
# slider_9_min6dB   0.356405      0.399298               0.496277
# slider_10_0dB     0.668862      0.706058               0.748839
# slider_10_6dB     0.731107      0.778349               0.817551
# slider_10_min6dB  0.540257      0.568331               0.605609
# slider_11_0dB     0.265345      0.334276               0.282988
# slider_11_6dB     0.369436      0.519092               0.390756
# slider_11_min6dB  0.254987      0.268577               0.253089
# valve_12_0dB      0.201390      0.153648               0.186198
# valve_12_6dB      0.195348      0.141147               0.177108
# valve_12_min6dB   0.221010      0.170735               0.204093
# valve_13_0dB      0.331430      0.370187               0.349751
# valve_13_6dB      0.372484      0.439317               0.429111
# valve_13_min6dB   0.252812      0.282935               0.271843
# valve_14_0dB      0.279878      0.190915               0.243973
# valve_14_6dB      0.297791      0.175778               0.242591
# valve_14_min6dB   0.204944      0.169335               0.194459
# valve_15_0dB      0.232418      0.207091               0.216696
# valve_15_6dB      0.275159      0.268677               0.267623
# valve_15_min6dB   0.214071      0.194806               0.189062
#
#                   AE_sound_FiLM_embed_64 Machine Name  id     SNR  ID
# fan_0_0dB                       0.541235          fan   0     0dB  00
# fan_0_6dB                       0.732986          fan   0     6dB  00
# fan_0_min6dB                    0.518713          fan   0  min6dB  00
# fan_1_0dB                       0.855876          fan   1     0dB  02
# fan_1_6dB                       0.934815          fan   1     6dB  02
# fan_1_min6dB                    0.627942          fan   1  min6dB  02
# fan_2_0dB                       0.661559          fan   2     0dB  04
# fan_2_6dB                       0.846472          fan   2     6dB  04
# fan_2_min6dB                    0.457461          fan   2  min6dB  04
# fan_3_0dB                       0.949474          fan   3     0dB  06
# fan_3_6dB                       0.961199          fan   3     6dB  06
# fan_3_min6dB                    0.768078          fan   3  min6dB  06
# pump_4_0dB                      0.457601         pump   4     0dB  00
# pump_4_6dB                      0.526184         pump   4     6dB  00
# pump_4_min6dB                   0.408750         pump   4  min6dB  00
# pump_5_0dB                      0.278871         pump   5     0dB  02
# pump_5_6dB                      0.286147         pump   5     6dB  02
# pump_5_min6dB                   0.238633         pump   5  min6dB  02
# pump_6_0dB                      0.869397         pump   6     0dB  04
# pump_6_6dB                      0.916413         pump   6     6dB  04
# pump_6_min6dB                   0.784257         pump   6  min6dB  04
# pump_7_0dB                      0.227323         pump   7     0dB  06
# pump_7_6dB                      0.240170         pump   7     6dB  06
# pump_7_min6dB                   0.206551         pump   7  min6dB  06
# slider_8_0dB                    0.930359       slider   8     0dB  00
# slider_8_6dB                    0.985614       slider   8     6dB  00
# slider_8_min6dB                 0.832555       slider   8  min6dB  00
# slider_9_0dB                    0.643090       slider   9     0dB  02
# slider_9_6dB                    0.622236       slider   9     6dB  02
# slider_9_min6dB                 0.481536       slider   9  min6dB  02
# slider_10_0dB                   0.799161       slider  10     0dB  04
# slider_10_6dB                   0.841408       slider  10     6dB  04
# slider_10_min6dB                0.634451       slider  10  min6dB  04
# slider_11_0dB                   0.293962       slider  11     0dB  06
# slider_11_6dB                   0.406884       slider  11     6dB  06
# slider_11_min6dB                0.254329       slider  11  min6dB  06
# valve_12_0dB                    0.183469        valve  12     0dB  00
# valve_12_6dB                    0.177624        valve  12     6dB  00
# valve_12_min6dB                 0.197539        valve  12  min6dB  00
# valve_13_0dB                    0.349498        valve  13     0dB  02
# valve_13_6dB                    0.421603        valve  13     6dB  02
# valve_13_min6dB                 0.268823        valve  13  min6dB  02
# valve_14_0dB                    0.237564        valve  14     0dB  04
# valve_14_6dB                    0.231902        valve  14     6dB  04
# valve_14_min6dB                 0.189004        valve  14  min6dB  04
# valve_15_0dB                    0.223974        valve  15     0dB  06
# valve_15_6dB                    0.282344        valve  15     6dB  06
# valve_15_min6dB                 0.187572        valve  15  min6dB  06

# %%
subset_df =  results_df[
          [
               "Machine Name",
               "ID",
               'AE_sound',
               'AE_sound_all', 
               'AE_sound_FiLM_one_hot',
               'AE_sound_FiLM_embed_64'
            ]].groupby(["Machine Name","ID"]).mean()
subset_df
# Out:
#                  AE_sound  AE_sound_all  AE_sound_FiLM_one_hot  \
# Machine Name ID
# fan          00  0.628820      0.561031               0.583885
#              02  0.790533      0.689281               0.805560
#              04  0.685375      0.630769               0.655186
#              06  0.904974      0.693511               0.828643
# pump         00  0.441306      0.291124               0.397913
#              02  0.231663      0.261320               0.257605
#              04  0.865866      0.502178               0.868287
#              06  0.246689      0.163298               0.198571
# slider       00  0.922806      0.918595               0.932637
#              02  0.323080      0.424599               0.627896
#              04  0.646742      0.684246               0.723999
#              06  0.296589      0.373982               0.308944
# valve        00  0.205916      0.155177               0.189133
#              02  0.318909      0.364146               0.350235
#              04  0.260871      0.178676               0.227008
#              06  0.240549      0.223525               0.224460
#
#                  AE_sound_FiLM_embed_64
# Machine Name ID
# fan          00                0.597645
#              02                0.806211
#              04                0.655164
#              06                0.892917
# pump         00                0.464179
#              02                0.267884
#              04                0.856689
#              06                0.224681
# slider       00                0.916176
#              02                0.582287
#              04                0.758340
#              06                0.318392
# valve        00                0.186211
#              02                0.346641
#              04                0.219490
#              06                0.231296

# %%
subset_and_ranks_df = pd.concat([subset_df, mean_rank_row])
subset_and_ranks_df
# Out:
#               AE_sound  AE_sound_all  AE_sound_FiLM_one_hot  \
# (fan, 00)     0.628820      0.561031               0.583885
# (fan, 02)     0.790533      0.689281               0.805560
# (fan, 04)     0.685375      0.630769               0.655186
# (fan, 06)     0.904974      0.693511               0.828643
# (pump, 00)    0.441306      0.291124               0.397913
# (pump, 02)    0.231663      0.261320               0.257605
# (pump, 04)    0.865866      0.502178               0.868287
# (pump, 06)    0.246689      0.163298               0.198571
# (slider, 00)  0.922806      0.918595               0.932637
# (slider, 02)  0.323080      0.424599               0.627896
# (slider, 04)  0.646742      0.684246               0.723999
# (slider, 06)  0.296589      0.373982               0.308944
# (valve, 00)   0.205916      0.155177               0.189133
# (valve, 02)   0.318909      0.364146               0.350235
# (valve, 04)   0.260871      0.178676               0.227008
# (valve, 06)   0.240549      0.223525               0.224460
# average rank  2.229167      3.250000               2.333333
#
#               AE_sound_FiLM_embed_64
# (fan, 00)                   0.597645
# (fan, 02)                   0.806211
# (fan, 04)                   0.655164
# (fan, 06)                   0.892917
# (pump, 00)                  0.464179
# (pump, 02)                  0.267884
# (pump, 04)                  0.856689
# (pump, 06)                  0.224681
# (slider, 00)                0.916176
# (slider, 02)                0.582287
# (slider, 04)                0.758340
# (slider, 06)                0.318392
# (valve, 00)                 0.186211
# (valve, 02)                 0.346641
# (valve, 04)                 0.219490
# (valve, 06)                 0.231296
# average rank                2.187500

# %%
table_cols = [
           "AE_sound",
           'AE_sound_all', 
           'AE_sound_FiLM_one_hot',
           'AE_sound_FiLM_embed_64'
          ]

results_table_short = subset_and_ranks_df[table_cols]
formatted_col_map= {
           "AE_sound": "AE separate (reference)",
           "AE_sound_all": "AE no cond.", 
           "AE_sound_FiLM_one_hot"  :"AE FiLM one hot",  
           "AE_sound_FiLM_embed_64": "AE FiLM embed"
}
formatted_results_table_short = results_table_short.rename(columns=formatted_col_map, errors="raise")
formatted_results_table_short
# Out:
#               AE separate (reference)  AE no cond.  AE FiLM one hot  \
# (fan, 00)                    0.628820     0.561031         0.583885
# (fan, 02)                    0.790533     0.689281         0.805560
# (fan, 04)                    0.685375     0.630769         0.655186
# (fan, 06)                    0.904974     0.693511         0.828643
# (pump, 00)                   0.441306     0.291124         0.397913
# (pump, 02)                   0.231663     0.261320         0.257605
# (pump, 04)                   0.865866     0.502178         0.868287
# (pump, 06)                   0.246689     0.163298         0.198571
# (slider, 00)                 0.922806     0.918595         0.932637
# (slider, 02)                 0.323080     0.424599         0.627896
# (slider, 04)                 0.646742     0.684246         0.723999
# (slider, 06)                 0.296589     0.373982         0.308944
# (valve, 00)                  0.205916     0.155177         0.189133
# (valve, 02)                  0.318909     0.364146         0.350235
# (valve, 04)                  0.260871     0.178676         0.227008
# (valve, 06)                  0.240549     0.223525         0.224460
# average rank                 2.229167     3.250000         2.333333
#
#               AE FiLM embed
# (fan, 00)          0.597645
# (fan, 02)          0.806211
# (fan, 04)          0.655164
# (fan, 06)          0.892917
# (pump, 00)         0.464179
# (pump, 02)         0.267884
# (pump, 04)         0.856689
# (pump, 06)         0.224681
# (slider, 00)       0.916176
# (slider, 02)       0.582287
# (slider, 04)       0.758340
# (slider, 06)       0.318392
# (valve, 00)        0.186211
# (valve, 02)        0.346641
# (valve, 04)        0.219490
# (valve, 06)        0.231296
# average rank       2.187500

# %%
print(formatted_results_table_short.to_latex( columns=formatted_results_table_short.columns, float_format='%.3f'))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  AE separate (reference) &  AE no cond. &  AE FiLM one hot &  AE FiLM embed \\
# \midrule
# (fan, 00)    &                    0.629 &        0.561 &            0.584 &          0.598 \\
# (fan, 02)    &                    0.791 &        0.689 &            0.806 &          0.806 \\
# (fan, 04)    &                    0.685 &        0.631 &            0.655 &          0.655 \\
# (fan, 06)    &                    0.905 &        0.694 &            0.829 &          0.893 \\
# (pump, 00)   &                    0.441 &        0.291 &            0.398 &          0.464 \\
# (pump, 02)   &                    0.232 &        0.261 &            0.258 &          0.268 \\
# (pump, 04)   &                    0.866 &        0.502 &            0.868 &          0.857 \\
# (pump, 06)   &                    0.247 &        0.163 &            0.199 &          0.225 \\
# (slider, 00) &                    0.923 &        0.919 &            0.933 &          0.916 \\
# (slider, 02) &                    0.323 &        0.425 &            0.628 &          0.582 \\
# (slider, 04) &                    0.647 &        0.684 &            0.724 &          0.758 \\
# (slider, 06) &                    0.297 &        0.374 &            0.309 &          0.318 \\
# (valve, 00)  &                    0.206 &        0.155 &            0.189 &          0.186 \\
# (valve, 02)  &                    0.319 &        0.364 &            0.350 &          0.347 \\
# (valve, 04)  &                    0.261 &        0.179 &            0.227 &          0.219 \\
# (valve, 06)  &                    0.241 &        0.224 &            0.224 &          0.231 \\
# average rank &                    2.229 &        3.250 &            2.333 &          2.188 \\
# \bottomrule
# \end{tabular}

# %%
results_ranks_df_print= pd.concat([results_df_print, mean_rank_row])
results_ranks_df_print[["Machine Name", "id", "SNR"]] = pd.DataFrame([x.split('_') for x in results_ranks_df_print.index.tolist()], index=results_ranks_df_print.index)

formatted_results_ranks_df_print= results_ranks_df_print.rename(columns=formatted_col_map, errors="raise")


formatted_results_ranks_df_print = formatted_results_ranks_df_print[[
    "Machine Name",
    "id",
    "SNR",
    "AE separate (reference)",
    "AE no cond.", 
    "AE FiLM one hot",  
    "AE FiLM embed"
]]
formatted_results_ranks_df_print
# Out:
#                   Machine Name    id     SNR AE separate (reference)  \
# fan_0_0dB                  fan     0     0dB             0.564±0.011
# fan_0_6dB                  fan     0     6dB             0.783±0.005
# fan_0_min6dB               fan     0  min6dB              0.54±0.005
# fan_1_0dB                  fan     1     0dB             0.816±0.045
# fan_1_6dB                  fan     1     6dB             0.963±0.005
# fan_1_min6dB               fan     1  min6dB             0.593±0.005
# fan_2_0dB                  fan     2     0dB             0.682±0.007
# fan_2_6dB                  fan     2     6dB             0.912±0.003
# fan_2_min6dB               fan     2  min6dB             0.462±0.003
# fan_3_0dB                  fan     3     0dB             0.963±0.003
# fan_3_6dB                  fan     3     6dB             0.998±0.002
# fan_3_min6dB               fan     3  min6dB             0.754±0.018
# pump_4_0dB                pump     4     0dB             0.399±0.036
# pump_4_6dB                pump     4     6dB             0.593±0.069
# pump_4_min6dB             pump     4  min6dB             0.332±0.009
# pump_5_0dB                pump     5     0dB             0.249±0.013
# pump_5_6dB                pump     5     6dB             0.256±0.028
# pump_5_min6dB             pump     5  min6dB              0.19±0.014
# pump_6_0dB                pump     6     0dB             0.878±0.043
# pump_6_6dB                pump     6     6dB             0.968±0.017
# pump_6_min6dB             pump     6  min6dB             0.752±0.023
# pump_7_0dB                pump     7     0dB             0.234±0.029
# pump_7_6dB                pump     7     6dB             0.286±0.076
# pump_7_min6dB             pump     7  min6dB              0.22±0.012
# slider_8_0dB            slider     8     0dB             0.934±0.005
# slider_8_6dB            slider     8     6dB               0.992±0.0
# slider_8_min6dB         slider     8  min6dB             0.842±0.009
# slider_9_0dB            slider     9     0dB             0.357±0.007
# slider_9_6dB            slider     9     6dB             0.256±0.007
# slider_9_min6dB         slider     9  min6dB             0.356±0.006
# slider_10_0dB           slider    10     0dB             0.669±0.093
# slider_10_6dB           slider    10     6dB             0.731±0.208
# slider_10_min6dB        slider    10  min6dB              0.54±0.025
# slider_11_0dB           slider    11     0dB             0.265±0.012
# slider_11_6dB           slider    11     6dB             0.369±0.007
# slider_11_min6dB        slider    11  min6dB             0.255±0.007
# valve_12_0dB             valve    12     0dB             0.201±0.009
# valve_12_6dB             valve    12     6dB              0.195±0.03
# valve_12_min6dB          valve    12  min6dB              0.221±0.01
# valve_13_0dB             valve    13     0dB             0.331±0.002
# valve_13_6dB             valve    13     6dB             0.372±0.007
# valve_13_min6dB          valve    13  min6dB              0.253±0.01
# valve_14_0dB             valve    14     0dB              0.28±0.026
# valve_14_6dB             valve    14     6dB             0.298±0.032
# valve_14_min6dB          valve    14  min6dB             0.205±0.016
# valve_15_0dB             valve    15     0dB             0.232±0.013
# valve_15_6dB             valve    15     6dB             0.275±0.009
# valve_15_min6dB          valve    15  min6dB             0.214±0.012
# average rank      average rank  None    None                 2.22917
#
#                   AE no cond. AE FiLM one hot AE FiLM embed
# fan_0_0dB         0.521±0.021     0.523±0.023   0.541±0.015
# fan_0_6dB         0.644±0.019     0.719±0.034   0.733±0.011
# fan_0_min6dB      0.518±0.015      0.51±0.014   0.519±0.011
# fan_1_0dB          0.67±0.054      0.848±0.01   0.856±0.006
# fan_1_6dB         0.913±0.012     0.947±0.015   0.935±0.013
# fan_1_min6dB      0.485±0.011     0.622±0.012   0.628±0.014
# fan_2_0dB         0.614±0.006     0.663±0.007   0.662±0.025
# fan_2_6dB         0.847±0.014     0.858±0.011   0.846±0.014
# fan_2_min6dB      0.431±0.004     0.445±0.006   0.457±0.014
# fan_3_0dB         0.704±0.079     0.892±0.012   0.949±0.031
# fan_3_6dB          0.913±0.01     0.934±0.001   0.961±0.021
# fan_3_min6dB      0.464±0.024      0.659±0.03   0.768±0.078
# pump_4_0dB        0.273±0.022     0.378±0.041   0.458±0.075
# pump_4_6dB        0.295±0.048     0.467±0.052   0.526±0.069
# pump_4_min6dB     0.305±0.016     0.349±0.038   0.409±0.047
# pump_5_0dB        0.266±0.034     0.261±0.019   0.279±0.044
# pump_5_6dB          0.28±0.03      0.28±0.025    0.286±0.06
# pump_5_min6dB     0.239±0.023     0.232±0.021   0.239±0.032
# pump_6_0dB         0.482±0.09     0.878±0.019   0.869±0.018
# pump_6_6dB         0.61±0.064     0.934±0.029   0.916±0.015
# pump_6_min6dB     0.414±0.073     0.793±0.022   0.784±0.012
# pump_7_0dB        0.161±0.002       0.2±0.019   0.227±0.042
# pump_7_6dB        0.153±0.001     0.201±0.034    0.24±0.068
# pump_7_min6dB     0.176±0.004     0.195±0.014   0.207±0.022
# slider_8_0dB      0.919±0.008     0.947±0.006    0.93±0.011
# slider_8_6dB      0.981±0.009     0.992±0.001   0.986±0.004
# slider_8_min6dB    0.857±0.01     0.858±0.021   0.833±0.017
# slider_9_0dB      0.505±0.042     0.687±0.043   0.643±0.072
# slider_9_6dB       0.369±0.04       0.7±0.094   0.622±0.175
# slider_9_min6dB   0.399±0.019     0.496±0.024   0.482±0.039
# slider_10_0dB     0.706±0.008     0.749±0.013   0.799±0.032
# slider_10_6dB     0.778±0.017     0.818±0.015   0.841±0.021
# slider_10_min6dB  0.568±0.003     0.606±0.016   0.634±0.025
# slider_11_0dB     0.334±0.025     0.283±0.009   0.294±0.017
# slider_11_6dB     0.519±0.031     0.391±0.005   0.407±0.048
# slider_11_min6dB  0.269±0.013     0.253±0.006   0.254±0.002
# valve_12_0dB      0.154±0.001     0.186±0.013   0.183±0.006
# valve_12_6dB       0.141±0.01     0.177±0.008   0.178±0.024
# valve_12_min6dB   0.171±0.003     0.204±0.011    0.198±0.01
# valve_13_0dB       0.37±0.018      0.35±0.004    0.349±0.01
# valve_13_6dB      0.439±0.016     0.429±0.021   0.422±0.025
# valve_13_min6dB   0.283±0.004     0.272±0.007   0.269±0.001
# valve_14_0dB      0.191±0.013     0.244±0.009    0.238±0.02
# valve_14_6dB      0.176±0.007     0.243±0.001   0.232±0.013
# valve_14_min6dB   0.169±0.007     0.194±0.008   0.189±0.015
# valve_15_0dB      0.207±0.003     0.217±0.002    0.224±0.01
# valve_15_6dB      0.269±0.017     0.268±0.002   0.282±0.015
# valve_15_min6dB   0.195±0.001       0.189±0.0   0.188±0.002
# average rank             3.25         2.33333        2.1875

# %%
print(formatted_results_ranks_df_print.to_latex( columns=formatted_results_ranks_df_print.columns, index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#  Machine Name &    id &     SNR & AE separate (reference) &  AE no cond. & AE FiLM one hot & AE FiLM embed \\
# \midrule
#           fan &     0 &     0dB &             0.564±0.011 &  0.521±0.021 &     0.523±0.023 &   0.541±0.015 \\
#           fan &     0 &     6dB &             0.783±0.005 &  0.644±0.019 &     0.719±0.034 &   0.733±0.011 \\
#           fan &     0 &  min6dB &              0.54±0.005 &  0.518±0.015 &      0.51±0.014 &   0.519±0.011 \\
#           fan &     1 &     0dB &             0.816±0.045 &   0.67±0.054 &      0.848±0.01 &   0.856±0.006 \\
#           fan &     1 &     6dB &             0.963±0.005 &  0.913±0.012 &     0.947±0.015 &   0.935±0.013 \\
#           fan &     1 &  min6dB &             0.593±0.005 &  0.485±0.011 &     0.622±0.012 &   0.628±0.014 \\
#           fan &     2 &     0dB &             0.682±0.007 &  0.614±0.006 &     0.663±0.007 &   0.662±0.025 \\
#           fan &     2 &     6dB &             0.912±0.003 &  0.847±0.014 &     0.858±0.011 &   0.846±0.014 \\
#           fan &     2 &  min6dB &             0.462±0.003 &  0.431±0.004 &     0.445±0.006 &   0.457±0.014 \\
#           fan &     3 &     0dB &             0.963±0.003 &  0.704±0.079 &     0.892±0.012 &   0.949±0.031 \\
#           fan &     3 &     6dB &             0.998±0.002 &   0.913±0.01 &     0.934±0.001 &   0.961±0.021 \\
#           fan &     3 &  min6dB &             0.754±0.018 &  0.464±0.024 &      0.659±0.03 &   0.768±0.078 \\
#          pump &     4 &     0dB &             0.399±0.036 &  0.273±0.022 &     0.378±0.041 &   0.458±0.075 \\
#          pump &     4 &     6dB &             0.593±0.069 &  0.295±0.048 &     0.467±0.052 &   0.526±0.069 \\
#          pump &     4 &  min6dB &             0.332±0.009 &  0.305±0.016 &     0.349±0.038 &   0.409±0.047 \\
#          pump &     5 &     0dB &             0.249±0.013 &  0.266±0.034 &     0.261±0.019 &   0.279±0.044 \\
#          pump &     5 &     6dB &             0.256±0.028 &    0.28±0.03 &      0.28±0.025 &    0.286±0.06 \\
#          pump &     5 &  min6dB &              0.19±0.014 &  0.239±0.023 &     0.232±0.021 &   0.239±0.032 \\
#          pump &     6 &     0dB &             0.878±0.043 &   0.482±0.09 &     0.878±0.019 &   0.869±0.018 \\
#          pump &     6 &     6dB &             0.968±0.017 &   0.61±0.064 &     0.934±0.029 &   0.916±0.015 \\
#          pump &     6 &  min6dB &             0.752±0.023 &  0.414±0.073 &     0.793±0.022 &   0.784±0.012 \\
#          pump &     7 &     0dB &             0.234±0.029 &  0.161±0.002 &       0.2±0.019 &   0.227±0.042 \\
#          pump &     7 &     6dB &             0.286±0.076 &  0.153±0.001 &     0.201±0.034 &    0.24±0.068 \\
#          pump &     7 &  min6dB &              0.22±0.012 &  0.176±0.004 &     0.195±0.014 &   0.207±0.022 \\
#        slider &     8 &     0dB &             0.934±0.005 &  0.919±0.008 &     0.947±0.006 &    0.93±0.011 \\
#        slider &     8 &     6dB &               0.992±0.0 &  0.981±0.009 &     0.992±0.001 &   0.986±0.004 \\
#        slider &     8 &  min6dB &             0.842±0.009 &   0.857±0.01 &     0.858±0.021 &   0.833±0.017 \\
#        slider &     9 &     0dB &             0.357±0.007 &  0.505±0.042 &     0.687±0.043 &   0.643±0.072 \\
#        slider &     9 &     6dB &             0.256±0.007 &   0.369±0.04 &       0.7±0.094 &   0.622±0.175 \\
#        slider &     9 &  min6dB &             0.356±0.006 &  0.399±0.019 &     0.496±0.024 &   0.482±0.039 \\
#        slider &    10 &     0dB &             0.669±0.093 &  0.706±0.008 &     0.749±0.013 &   0.799±0.032 \\
#        slider &    10 &     6dB &             0.731±0.208 &  0.778±0.017 &     0.818±0.015 &   0.841±0.021 \\
#        slider &    10 &  min6dB &              0.54±0.025 &  0.568±0.003 &     0.606±0.016 &   0.634±0.025 \\
#        slider &    11 &     0dB &             0.265±0.012 &  0.334±0.025 &     0.283±0.009 &   0.294±0.017 \\
#        slider &    11 &     6dB &             0.369±0.007 &  0.519±0.031 &     0.391±0.005 &   0.407±0.048 \\
#        slider &    11 &  min6dB &             0.255±0.007 &  0.269±0.013 &     0.253±0.006 &   0.254±0.002 \\
#         valve &    12 &     0dB &             0.201±0.009 &  0.154±0.001 &     0.186±0.013 &   0.183±0.006 \\
#         valve &    12 &     6dB &              0.195±0.03 &   0.141±0.01 &     0.177±0.008 &   0.178±0.024 \\
#         valve &    12 &  min6dB &              0.221±0.01 &  0.171±0.003 &     0.204±0.011 &    0.198±0.01 \\
#         valve &    13 &     0dB &             0.331±0.002 &   0.37±0.018 &      0.35±0.004 &    0.349±0.01 \\
#         valve &    13 &     6dB &             0.372±0.007 &  0.439±0.016 &     0.429±0.021 &   0.422±0.025 \\
#         valve &    13 &  min6dB &              0.253±0.01 &  0.283±0.004 &     0.272±0.007 &   0.269±0.001 \\
#         valve &    14 &     0dB &              0.28±0.026 &  0.191±0.013 &     0.244±0.009 &    0.238±0.02 \\
#         valve &    14 &     6dB &             0.298±0.032 &  0.176±0.007 &     0.243±0.001 &   0.232±0.013 \\
#         valve &    14 &  min6dB &             0.205±0.016 &  0.169±0.007 &     0.194±0.008 &   0.189±0.015 \\
#         valve &    15 &     0dB &             0.232±0.013 &  0.207±0.003 &     0.217±0.002 &    0.224±0.01 \\
#         valve &    15 &     6dB &             0.275±0.009 &  0.269±0.017 &     0.268±0.002 &   0.282±0.015 \\
#         valve &    15 &  min6dB &             0.214±0.012 &  0.195±0.001 &       0.189±0.0 &   0.188±0.002 \\
#  average rank &  None &    None &                 2.22917 &         3.25 &         2.33333 &        2.1875 \\
# \bottomrule
# \end{tabular}

# %%
print(formatted_results_table_short.to_latex( columns=formatted_results_table_short.columns, float_format='%.3f'))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  AE separate (reference) &  AE no cond. &  AE FiLM one hot &  AE FiLM embed \\
# \midrule
# (fan, 00)    &                    0.629 &        0.561 &            0.584 &          0.598 \\
# (fan, 02)    &                    0.791 &        0.689 &            0.806 &          0.806 \\
# (fan, 04)    &                    0.685 &        0.631 &            0.655 &          0.655 \\
# (fan, 06)    &                    0.905 &        0.694 &            0.829 &          0.893 \\
# (pump, 00)   &                    0.441 &        0.291 &            0.398 &          0.464 \\
# (pump, 02)   &                    0.232 &        0.261 &            0.258 &          0.268 \\
# (pump, 04)   &                    0.866 &        0.502 &            0.868 &          0.857 \\
# (pump, 06)   &                    0.247 &        0.163 &            0.199 &          0.225 \\
# (slider, 00) &                    0.923 &        0.919 &            0.933 &          0.916 \\
# (slider, 02) &                    0.323 &        0.425 &            0.628 &          0.582 \\
# (slider, 04) &                    0.647 &        0.684 &            0.724 &          0.758 \\
# (slider, 06) &                    0.297 &        0.374 &            0.309 &          0.318 \\
# (valve, 00)  &                    0.206 &        0.155 &            0.189 &          0.186 \\
# (valve, 02)  &                    0.319 &        0.364 &            0.350 &          0.347 \\
# (valve, 04)  &                    0.261 &        0.179 &            0.227 &          0.219 \\
# (valve, 06)  &                    0.241 &        0.224 &            0.224 &          0.231 \\
# average rank &                    2.229 &        3.250 &            2.333 &          2.188 \\
# \bottomrule
# \end{tabular}
